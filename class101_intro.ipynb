# %% [markdown]
# # '클래스101'에서 '강의 소개' 내용 가져오기

# %% [markdown]
# ## 1) 패키지와 모듈 설치 및 input(키워드) 입력

# %%
### 참고사이트: https://coding-kindergarten.tistory.com/91

#step1.selenium 패키지와 time 모듈 import
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import numpy as np
import pandas as pd
from selenium.webdriver.chrome.options import Options
options = Options()

# chrome을 전체화면으로 넓히는 옵션입니다.
options.add_argument('--start-fullscreen')


#step2.검색할 키워드 입력 
query = input()

#step3.크롬드라이버로 url로 접속
url = 'https://class101.net/categories/'
driver = webdriver.Chrome(executable_path="/Users/USER/Desktop/datamining/chromedriver.exe", chrome_options=options)  ##크롬드라이버가 설치된 위치
driver.get(url)
time.sleep(3)

#step4.검색창에 키워드 입력 후 엔터
search_box = driver.find_element_by_css_selector(".SearchInput__Input-go705p-2.bxkgtv")
search_box.send_keys(query)
search_box.send_keys(Keys.RETURN)
time.sleep(2)


## 스크롤하기 ##
#ActionChains모듈 가져오기
from selenium.webdriver import ActionChains

#ActionChains생성
action = ActionChains(driver)
# Out:
# 드로잉
# <ipython-input-97-6bec5f845165>:20: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="/Users/USER/Desktop/datamining/chromedriver.exe", chrome_options=options)  ##크롬드라이버가 설치된 위치
# <ipython-input-97-6bec5f845165>:20: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path="/Users/USER/Desktop/datamining/chromedriver.exe", chrome_options=options)  ##크롬드라이버가 설치된 위치
# <ipython-input-97-6bec5f845165>:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_box = driver.find_element_by_css_selector(".SearchInput__Input-go705p-2.bxkgtv")

# %%
## driver.back() #뒤로가기

# %% [markdown]
# ## 2) 필요한 리스트 만들어주기

# %%
## 리스트 리셋할 때 사용

title_list=[] ## 강의명 리스트
intro=[]      ## 강의 소개글을 tag<p> 단위로 받아올 리스트
intro_list=[] ## 강의 소개글을 강의 단위로 저장할 리스트
keyword=[]    ## 강의별 검색 키워드 저장 리스트

# %% [markdown]
# ## 3) 검색 결과의 1페이지에 있는 강의 전체 크롤링 (페이지당 60개)  ---1페이지에 대한 코드만 작성
# - 1페이지 당 60개의 강의가 있음
# - 상단 8개 / 하단 52개로 섹션이 구분되어 있음
# - 상단과 하단 강의를 구분해서 for문을 돌려줌

# %% [markdown]
# ### 3-1) 1페이지 상단 강의 8개 크롤링

# %%
for n in range(1,9):   ## 1페이지 상단 강의1~강의8 크롤링 
    x_path = '//*[@id="wrapper"]/div/div[3]/div/section/div/div[4]/div[3]/div[1]/ul/li[{0}]/div/a'.format(n)
             
    driver.find_element_by_xpath(x_path).click()
    time.sleep(2)
    
        
    intro_text = driver.find_elements_by_tag_name("p") ## 소개글 가져오기
    intro=[]
    
    for t in intro_text:
        text = t.text
        intro.append(text)
    intro_list.append(' '.join(intro)) ## 소개글 가져와서 리스트에 저장
    

    keyword.append(query) ## 키워드 리스트 업데이트
    driver.back() #뒤로가기
    time.sleep(2)
# Out:
# <ipython-input-170-05ef1dfcad37>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(x_path).click()
# <ipython-input-170-05ef1dfcad37>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   intro_text = driver.find_elements_by_tag_name("p") ## 소개글 가져오기

# %% [markdown]
# ### 3-2) 1페이지 하단 강의 52개 크롤링

# %%
for n in range(1,53):   ## 1페이지 하단 강의1~강의52까지 크롤링 
    x_path = '//*[@id="wrapper"]/div/div[3]/div/section/div/div[4]/div[3]/div[4]/div/div/ul/li[{0}]/div/a'.format(n)
             
    driver.find_element_by_xpath(x_path).click()
    time.sleep(2)
    
        
    intro_text = driver.find_elements_by_tag_name("p") ## 소개글 가져오기
    intro=[]
    
    for t in intro_text:
        text = t.text
        intro.append(text)
    intro_list.append(' '.join(intro)) ## 소개글 가져와서 리스트에 저장
    

    keyword.append(query) ## 키워드 리스트 업데이트
    driver.back() #뒤로가기
    time.sleep(2)
# Out:
# <ipython-input-171-2c8c0faa04ef>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(x_path).click()
# <ipython-input-171-2c8c0faa04ef>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   intro_text = driver.find_elements_by_tag_name("p") ## 소개글 가져오기

# %% [markdown]
# ## 4) 1페이지의 강의명 크롤링 (총 60개)

# %%
title_list=[]

# %%
titles = driver.find_elements_by_css_selector(".Card__Title-sc-1esp5o0-4.bVCpyh")

for i in titles:
    title = i.text
    title_list.append(title)
# Out:
# <ipython-input-174-55bc1a781b43>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   titles = driver.find_elements_by_css_selector(".Card__Title-sc-1esp5o0-4.bVCpyh")

# %%
title_list
# Out:
# ['[🎁연말특가] 겹겹이 쌓인 시간의 발자국까지, 펜으로 그리는 건축드로잉',
#  '[🏆TOP30] 어색한 그림은 이제 안녕! 드로잉 기초부터 시작하는 리니의 펜드로잉',
#  '[🎁연말특가] 펜 드로잉, 여행의 순간을 기록하다',
#  '[🎁연말특가] 후회 없는 마카 드로잉 입문편',
#  '[🎁연말특가] 아이패드로 힘들이지 않고 쉽게, 부드러운 인물 드로잉',
#  '[🎁연말특가] 면으로 쓱- 완성하는 기법, 면(Plane) 드로잉',
#  '[✔️수강생PICK] 마카와 펜, 드로잉북만 들고 떠나요! 마카로 담는 여행의 특별한 기억',
#  '[❤️1+1할인] 둡의 연필드로잉부터 채색까지',
#  '[❤️1+1할인] 인체 드로잉 기초부터, 디테일까지 인체 드로잉의 모든 것',
#  '[🎁연말특가] 흑백으로 그리는 빛나는 풍경 - 콘테 드로잉',
#  '[✔️수강생PICK] 그 시간의 온도를 그려요, 분위기 있는 오일파스텔 드로잉',
#  '[🎁연말특가] 맘껏 표현해봐! 드로잉 3대 법칙으로 7개 작품 완성하기',
#  '[✔️수강생PICK] 일기 쓰듯 한 장 한 장, 마카로 사각사각 데일리 드로잉',
#  '[🎁연말특가] 안녕 수채화, 못 그려도 괜찮아!',
#  '[✔️수강생PICK] 평범한 일상에 색을 더하는 시간, 자토의 아이패드 드로잉',
#  '[✔️수강생PICK] 선으로 모든 것을! 디지털 빈티지 라인 드로잉 (feat. iPad)',
#  '[🔥트렌드특가] 사물, 인물 그리고 풍경까지! 아이패드 드로잉의 모든 것',
#  '[🎁연말특가] 정교하게 그려내고 채색까지 끝내기, 펜드로잉 입문편',
#  '[101원] 갤럭시 탭 S7/S7+로 일상 드로잉하기!',
#  '[🎁연말특가] 감성을 담은 미니멀 일러스트! 별라랜드의 아이패드 드로잉',
#  '[🎁연말특가] 모두를 위한 인체 드로잉, 내 머릿속 캐릭터를 그려요',
#  '[🏆TOP30] 선으로 담아내는 감각적인 인물화, 콘(CON)의 아이패드 드로잉',
#  '[🎁연말특가] 그림과 친해지는 법, 매일 그려보는 라인 드로잉',
#  '[🎁연말특가] 아날로그와 디지털의 하모니. 일러스트 드로잉 베스트 모음',
#  '[✔️수강생PICK] 새로운 드로잉 기법의 설렘, 레트로 픽셀아트 드로잉',
#  '[✔️수강생PICK] Back to the Retro!나무13과 함께 레트로아이패드드로잉',
#  '[🎁연말특가] 조금 삐뚤어도 괜찮아! 무한한 선의 매력, 펜 드로잉',
#  '[🏆TOP30] 여행 드로잉, 꿈만 꾸지 마세요. 핀든아트와 여행, 그리다',
#  '[🔥트렌드특가] 텍스처가 살아있는 따듯한 아이패드 감성 드로잉',
#  '[🎁연말특가] One & Only! 라인 드로잉 자수는 처음이죠?',
#  '[🎁연말특가] 아이패드 하나로 배워 보는 두 가지 방식의 라인 드로잉',
#  '캔버스에서 창조하는 생생한 세계, POGO의 액션 판타지 드로잉',
#  '[🎁연말특가] 일러스트레이터 이이오의 담백한 아이패드 드로잉',
#  '[🔥트렌드특가] 5가지 스타일을 한 번에! 달콩의 아이패드 드로잉',
#  '[🎁연말특가] 숨겨왔던 나~의 그림 선 찾기, 러프 스케치부터 섬세한 드로잉까지',
#  '[❤️1+1할인] 따뜻하고 감성적인 그림 만족도 1위 아이패드 드로잉',
#  '[🎁연말특가] 스마트폰 하나로 즐기는 반짝반짝 캐릭터 드로잉',
#  '[🎁연말특가] 집에서 떠나는 방구석 여행, 선과 색으로 채워가는 아이패드 여행 드로잉',
#  '[🎁연말특가] 추억을 기록하는 드로잉. 자신감 넘치는 감성 펜 드로잉 입문 클래스',
#  '[🎁연말특가] 내면의 평온을 위한 그림 명상, 만다라 드로잉',
#  '[✔️수강생PICK] 오늘 느끼는 작은 행복, 과슈 드로잉 다이어리',
#  '[🏆TOP30] 크로키로 찾아가는 나만의 선, 나만의 드로잉',
#  '[🎁연말특가] 단시간에 분위기를 담는 그림 NamE의 감성 펜 드로잉',
#  '[✔️수강생PICK] 환상을 현실로 구체화하는 경험, 인디고의 두 번째 아이패드 드로잉',
#  '[❤️1+1할인] 귀여움 더하기 귀여움, 몽글몽글한 아이패드 드로잉의 모든 것!',
#  '[🎁연말특가] [라이프 스케치] 아름다운 일상의 순간을 기록하는 그림, 드로잉의 기술',
#  '[태블릿최저가] 수영복 입은 공주! 일러스트레이터 휴휴의 디지털 드로잉',
#  '[🎁연말특가] 일러스트와 만화, 그 경계를 허무는 이야기가 담긴 캐릭터 드로잉',
#  '[🔥트렌드특가] 내가 그리고, 네가 간직할 인공의 아이패드 드로잉',
#  '[🔥트렌드특가] 또 다른 나를 그리다, 동글의 아이패드 캐릭터 드로잉',
#  '[✔️수강생PICK] 손바닥 안에 그려내는 배낭여행자의 기록, 아이린의 여행드로잉 클래스',
#  '[🎁연말특가] 그날의 온도를 기록하는 법, 여행 드로잉 수채화와 캘리그라피',
#  '[✔️수강생PICK] 물 머금은 듯 부드러운 채색, 아이패드 드로잉',
#  '상상을 더 정교하게 만드는 선과 채색, 일러스트레이터 핀의 디지털 드로잉',
#  '[🎁연말특가] 조금 더 깊이 있게, 자연스러운 인체 드로잉을 위한 모든 것',
#  '[🎁연말특가] 쉽게 그리는 청그림의 색연필 여행드로잉! 따듯한 색감들로 채워요',
#  '[✔️수강생PICK] 자연스러운 표정과 포즈를 표현해요!일러스트레이터 노보듀스의 인물 기초 드로잉',
#  '[태블릿최저가] 드로잉부터 굿즈 제작까지! 익숙한 공간에 판타지를 담아 그리는 몽환적 일러스트',
#  '[🎁연말특가] 달콤한 낮잠 같은 색으로, 낮잠의 색연필 드로잉',
#  '[🔥트렌드특가] 환상 속 세계를 그려봐요, 일러스트레이터 웨지의 디지털 드로잉']

# %% [markdown]
# # 5) 크롤링 결과 확인 및 DataFrame으로 변환

# %%
print(len(title_list))
print(len(intro_list))
print(len(keyword))
# Out:
# 60
# 60
# 60

# %%
data = {"class_title" : title_list,
       "intro" : intro_list,
       "keyword" : keyword}

# %%
### DataFrame 행 넓이 최대 
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-181-c3b6d9bbd837>:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
### DataFrame형태로 변환

df = pd.DataFrame(data)
df
# Out:
#                                                class_title  \
# 0   [🎁연말특가] 겹겹이 쌓인 시간의 발자국까지, 펜으로 그리는 건축드로잉
# 1   [🏆TOP30] 어색한 그림은 이제 안녕! 드로잉 기초부터 시작하는 리니의 펜드로잉
# 2   [🎁연말특가] 펜 드로잉, 여행의 순간을 기록하다
# 3   [🎁연말특가] 후회 없는 마카 드로잉 입문편
# 4   [🎁연말특가] 아이패드로 힘들이지 않고 쉽게, 부드러운 인물 드로잉
# 5   [🎁연말특가] 면으로 쓱- 완성하는 기법, 면(Plane) 드로잉
# 6   [✔️수강생PICK] 마카와 펜, 드로잉북만 들고 떠나요! 마카로 담는 여행의 특별한 기억
# 7   [❤️1+1할인] 둡의 연필드로잉부터 채색까지
# 8   [❤️1+1할인] 인체 드로잉 기초부터, 디테일까지 인체 드로잉의 모든 것
# 9   [🎁연말특가] 흑백으로 그리는 빛나는 풍경 - 콘테 드로잉
# 10  [✔️수강생PICK] 그 시간의 온도를 그려요, 분위기 있는 오일파스텔 드로잉
# 11  [🎁연말특가] 맘껏 표현해봐! 드로잉 3대 법칙으로 7개 작품 완성하기
# 12  [✔️수강생PICK] 일기 쓰듯 한 장 한 장, 마카로 사각사각 데일리 드로잉
# 13  [🎁연말특가] 안녕 수채화, 못 그려도 괜찮아!
# 14  [✔️수강생PICK] 평범한 일상에 색을 더하는 시간, 자토의 아이패드 드로잉
# 15  [✔️수강생PICK] 선으로 모든 것을! 디지털 빈티지 라인 드로잉 (feat. iPad)
# 16  [🔥트렌드특가] 사물, 인물 그리고 풍경까지! 아이패드 드로잉의 모든 것
# 17  [🎁연말특가] 정교하게 그려내고 채색까지 끝내기, 펜드로잉 입문편
# 18  [101원] 갤럭시 탭 S7/S7+로 일상 드로잉하기!
# 19  [🎁연말특가] 감성을 담은 미니멀 일러스트! 별라랜드의 아이패드 드로잉
# 20  [🎁연말특가] 모두를 위한 인체 드로잉, 내 머릿속 캐릭터를 그려요
# 21  [🏆TOP30] 선으로 담아내는 감각적인 인물화, 콘(CON)의 아이패드 드로잉
# 22  [🎁연말특가] 그림과 친해지는 법, 매일 그려보는 라인 드로잉
# 23  [🎁연말특가] 아날로그와 디지털의 하모니. 일러스트 드로잉 베스트 모음
# 24  [✔️수강생PICK] 새로운 드로잉 기법의 설렘, 레트로 픽셀아트 드로잉
# 25  [✔️수강생PICK] Back to the Retro!나무13과 함께 레트로아이패드드로잉
# 26  [🎁연말특가] 조금 삐뚤어도 괜찮아! 무한한 선의 매력, 펜 드로잉
# 27  [🏆TOP30] 여행 드로잉, 꿈만 꾸지 마세요. 핀든아트와 여행, 그리다
# 28  [🔥트렌드특가] 텍스처가 살아있는 따듯한 아이패드 감성 드로잉
# 29  [🎁연말특가] One & Only! 라인 드로잉 자수는 처음이죠?
# 30  [🎁연말특가] 아이패드 하나로 배워 보는 두 가지 방식의 라인 드로잉
# 31  캔버스에서 창조하는 생생한 세계, POGO의 액션 판타지 드로잉
# 32  [🎁연말특가] 일러스트레이터 이이오의 담백한 아이패드 드로잉
# 33  [🔥트렌드특가] 5가지 스타일을 한 번에! 달콩의 아이패드 드로잉
# 34  [🎁연말특가] 숨겨왔던 나~의 그림 선 찾기, 러프 스케치부터 섬세한 드로잉까지
# 35  [❤️1+1할인] 따뜻하고 감성적인 그림 만족도 1위 아이패드 드로잉
# 36  [🎁연말특가] 스마트폰 하나로 즐기는 반짝반짝 캐릭터 드로잉
# 37  [🎁연말특가] 집에서 떠나는 방구석 여행, 선과 색으로 채워가는 아이패드 여행 드로잉
# 38  [🎁연말특가] 추억을 기록하는 드로잉. 자신감 넘치는 감성 펜 드로잉 입문 클래스
# 39  [🎁연말특가] 내면의 평온을 위한 그림 명상, 만다라 드로잉
# 40  [✔️수강생PICK] 오늘 느끼는 작은 행복, 과슈 드로잉 다이어리
# 41  [🏆TOP30] 크로키로 찾아가는 나만의 선, 나만의 드로잉
# 42  [🎁연말특가] 단시간에 분위기를 담는 그림 NamE의 감성 펜 드로잉
# 43  [✔️수강생PICK] 환상을 현실로 구체화하는 경험, 인디고의 두 번째 아이패드 드로잉
# 44  [❤️1+1할인] 귀여움 더하기 귀여움, 몽글몽글한 아이패드 드로잉의 모든 것!
# 45  [🎁연말특가] [라이프 스케치] 아름다운 일상의 순간을 기록하는 그림, 드로잉의 기술
# 46  [태블릿최저가] 수영복 입은 공주! 일러스트레이터 휴휴의 디지털 드로잉
# 47  [🎁연말특가] 일러스트와 만화, 그 경계를 허무는 이야기가 담긴 캐릭터 드로잉
# 48  [🔥트렌드특가] 내가 그리고, 네가 간직할 인공의 아이패드 드로잉
# 49  [🔥트렌드특가] 또 다른 나를 그리다, 동글의 아이패드 캐릭터 드로잉
# 50  [✔️수강생PICK] 손바닥 안에 그려내는 배낭여행자의 기록, 아이린의 여행드로잉 클래스
# 51  [🎁연말특가] 그날의 온도를 기록하는 법, 여행 드로잉 수채화와 캘리그라피
# 52  [✔️수강생PICK] 물 머금은 듯 부드러운 채색, 아이패드 드로잉
# 53  상상을 더 정교하게 만드는 선과 채색, 일러스트레이터 핀의 디지털 드로잉
# 54  [🎁연말특가] 조금 더 깊이 있게, 자연스러운 인체 드로잉을 위한 모든 것
# 55  [🎁연말특가] 쉽게 그리는 청그림의 색연필 여행드로잉! 따듯한 색감들로 채워요
# 56  [✔️수강생PICK] 자연스러운 표정과 포즈를 표현해요!일러스트레이터 노보듀스의 인물 기초 드로잉
# 57  [태블릿최저가] 드로잉부터 굿즈 제작까지! 익숙한 공간에 판타지를 담아 그리는 몽환적 일러스트
# 58  [🎁연말특가] 달콤한 낮잠 같은 색으로, 낮잠의 색연필 드로잉
# 59  [🔥트렌드특가] 환상 속 세계를 그려봐요, 일러스트레이터 웨지의 디지털 드로잉
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        intro  \
# 0    "1950년대, 종로" "통인동 보안여관" 누구나 그릴 수 있는 공간과 시점에 대해 드로잉의 시작, 연필소묘 건축마감재의 다양한 표현    저와 함께 종이에 펜으로 슥슥 그리는 건축일러스트의 매력을 경험해보세요. 일러스트레이터 '루시드로잉'입니다. 디자인을 전공했고, 건축소재 관련 일을 해왔습니다. 저는 오랜시간 우리주변의 건축물에 관심을 가져왔는데요, 건물들이 가진 저마다의 모습이 시간의 흐름에 따라 추억이 담긴 자화상으로 느껴져 흥미를 가지게 됐습니다.   우리의 일상이 녹아든 친숙한 건물들과 지금은 사라진 옛 우리의 건축물들에 대해 저만의 드로잉으로 그려가고 있어요. 지금도 흔히 볼 수 있는 익숙한 풍경도 있고, 우리는 볼 수 없는 자료속의 건물들도 보이지요? 모두 우리의 이야기를 담고 있는 건물들의 모습입니다.  가장 먼저 함께 "1950년대, 종로"라는 작품을 그려볼 거예요. 지금은 사라진 우리의 옛 근대건축물에 관심있는 루시드로잉의 건물시리즈 작품 중 하나입니다. 1950년대 종로에 있던 건물에서 당시의 레트로한 감성을 만나보세요. 이 건물은 건물 전면이 반듯하고, 건물 마감재 표현이 쉬운 편입니다. 하부단에 울퉁불퉁한 돌마감 외에 벽면은 간격이 큰 매지가 들어간 시멘트 회벽이라 약간의 터치만으로도 쉽게 표현할 수 있어요. 또 창문과 문, 건물의 올록볼록한 입체감이 건물드로잉을 연습하기에 좋아요. 우리나라 근대문학의 중심지로, 많은 예술인들의 혼과 숨결이 지나간 통인동 보안여관입니다. 지금도 경복궁 근처에 자리잡고 있는 통인동 보안여관은 복합예술문화공간으로 활용되고 있어요. 우리의 근대역사가 담긴 모던한 건물드로잉입니다. 통인동 보안여관은 건물자체의 입체감은 덜하지만 루시드로잉 그림의 포인트인 벽돌건물 디테일을 함께 그려보고 건물을 둘러싼 악세사리 (간판, 가로수, 화분)도 그려볼 수 있어요. 건축드로잉을 시작하기에 앞서, 어떤 건물을 그릴지 자료나 사진을 찾아야 해요. 저는 보통 직접 방문해서 사진을 찍거나 자료를 찾아서 그림을 그릴 대상을 정합니다. 굳이 직접 찾아가는 이유는, 내 취향에 따라 더 강조하고 싶은 디테일, 톤 등이 있기 때문에 건물을 살펴보고 공간을 느껴보기 위해서예요. 직접 건물을 보면, 사진만 보았을 때보다 더 많은 것을 느낄 수 있거든요. 또한 건물을 사진으로 남기는 것도 그림을 그리는 데 도움이 됩니다. 제가 건물 사진을 직접 찍고, 고르는 방법부터 함께 할게요.  그림을 그릴 멋진 건물을 정했다면 본격적으로 그림을 그려봐야겠죠! 가장 먼저 스케치를 해볼 거예요. 찍은 사진을 보고 연필로 연하게 밑그림을 그립니다. 건물의 구조를 살펴보고 앞으로 완성될 작품의 윤곽을 잡는 중요한 과정이에요!   컬러펜 중에서도 옅은 회색, 아이보리색 등 옅은색으로 밑그림을 조금 더 구체화합니다. 윤곽선을 정리하고 창문, 지붕, 기둥의 디테일 등 건물의 요소를 그려나갑니다.  기본선이 그려지면 마카로 건물의 톤을 표현합니다. 펜선이 많이 올라가기 때문에 주로 웜그레이, 베이지, 쿨그레이로 건물 배경색을 칠해주고, 그림자가 많이 지는 어두운 건물 내부의 경우 진한 마카로 깊이를 줍니다.   건물마다 가진 색을 2~3가지 이상의 펜을 섞어가며 소묘의 느낌을 살려 채색을 완성합니다. 한가지 컬러로 하나의 레이어를 그린다 생각하고 겹겹이 깊이감을 주어요. 저의 건물드로잉은 소묘적 기법과 컬러의 매치가 굉장히 중요한만큼, 채색을 완성하는 이 단계도 정말 중요하다고 할 수 있어요!  루시드로잉의 클래스는 투시점을 잡아 디테일의 정확성을 가지는 드로잉보다는 파사드(건축 전면)를 그리며, 건물의 기본구조와 건물마다 깃든 컬러감, 때로는 과감한 생략과 연출을 배워볼 예정입니다. 같은 건물을 그리더라도 저마다의 감각으로 다양한 톤의 건축일러스트가 나오겠죠?    또, 건축일러스트의 재밌는 점은 다양한 건축자재의 표현에 있습니다. 화려한 대리석, 컬러와 깨짐의 정도가 다양한 벽돌 벽면, 빛바랜 우드, 벗겨진 페인트 벽면 등 몇가지 컬러링 팁도 배워보세요. 나만의 시선으로 풍성한 컬러감의 그림이 만들어질겁니다.  10\n:\n37\n:\n18\n남음  클래스101 | 세상의 모든 클래스, 클래스101
# 1     드로잉의 기초, 관찰과 표현 건물 정면 스케치 하기 투시에 대한 모든 것      안녕하세요, 일러스트레이터 리니(Rini) 입니다! 현재 프리랜서로 일하며 클래스101에서 총 3개의 클래스를 진행하고 있어요.  '드로잉 기초부터 시작하는 리니의 펜드로잉', '마카&펜으로 기록하는 여행과 일상 드로잉'. '꿈꾸는 일상 공간 속의 나, 아이패드 드로잉'까지 수천명의 클래스메이트분들께 그림의 즐거움을 전달드리고 있어요. 최근에는 [나의 첫 아이패드 드로잉] 책을 출간했습니다.    대부분 제 클래스 중 하나를 들으면 다른 클래스도 꼭 들으시더라고요. 모두 제가 늘 강조하는 것이 무엇인지 아시기 때문이죠.  '단순히 따라 그리는 그림'이 아닌 '왜 이렇게 그려야 하는지 이해하고 그리는 그림'을 그리시면 좋겠어요.  그래서 제 일러스트 화풍이나 스타일을 떠나서, 드로잉 기초 이론에 따라 '그림 그리는 방법'을 가르쳐 드릴게요. 무작정 누군가의 그림 스타일을 따라가지 마시고, 드로잉 기초를 익힌 후에 여러분만의 스타일을 차근차근 만드시면 좋겠어요!  🌷위 사진은 오프라인 강의 때 수강생분들의 작품이에요. 모두 그림을 처음 그려보시는 분들의 작품이랍니다. 여러분도 충분히 하실 수 있어요!  📍 클래스 후기에서 수많은 분의 그림을 직접 확인해보세요! 그림을 처음 그리더라도 어떤 그림까지 그려낼 수 있는지 확인하실 수 있어요.   준비물도 간단해요. 어딜 가나 펼칠 수 있는 드로잉북과 연필, 펜만 있다면 내가 원하는 무엇이든, 내가 담고 싶은 어떤 곳이든 그려낼 수 있답니다.  선하나를 긋더라도 왜 그렇게 그어야 하는지 함께 이해하고 그려요! 그래야 나중에 혼자서도 멋진 그림을 그릴 수 있겠죠?   ✍️아래 그림도 여러분과 같은, 처음 펜드로잉을 시작한 수강생의 작품입니다!  기본적인 드로잉 기초를 배우고 나면, 혼자서 그려도 '어색하지 않은 그림'을 그리실 수 있어요. 최대한 쉽고 재밌게 가르쳐 드릴게요. 여러 가지 굵기의 펜을 사용하여 그리면 더 재미있게 그림을 완성하실 수 있답니다.   제 클래스는 그림을 한 번도 '제대로' 배워보지 않은 분들을 중점으로 진행해요. 여러 텍스처 표현법과 투시 이론까지 담겨 있으니 그림을 어느 정도 그려보신 분들도 새로운 것을 배우실 수 있을 거예요.  8개의 챕터로 진행되며, 총 12개의 작품(연습용 드로잉 제외)을 만들어 봅니다. 보통 A4용지 크기를 기준으로 사물이나 간단한 대상은 1~2시간, 복잡한 풍경이나 어반 드로잉은 2~4시간 정도 소요됩니다.  📍 소요 시간은 개인에 따라 진행 속도에 차이가 있을 수 있습니다.  그림을 그리기 위해서 알아야 할 드로잉 기초에 대해 배워보아요. 쉽고 꼼꼼하게 설명해드릴게요. 펜 사용법, 선 긋는 방법, 사물을 관찰하고 표현하는 방법까지. 기초적인 것을 탄탄하게 익혀놓으면 그림 실력은 더 빠르고 안정적으로 발전할 수 있어요.    그림도 그리는 순서가 있어요. 그 순서만 알아도 그림이 훨씬 쉬워지죠. 대상을 단순화해서 바라보는 법, 비율 잡는 법을 체계적으로 배워보세요. 복잡하고 어려운 대상도 더 자신있게 그릴 수 있어요.     평소에 열심히 그린 그림들, 어딘가 모르게 어색하진 않으신가요? 바로 투시 원근법에 대해 모르시기 때문이에요. 투시를 알게 되면 사물, 풍경, 인체 그 무엇이든 더 자연스럽게 그릴 수 있어요. 한번 배워놓으면 어떤 그림을 그리더라도 스스로 적용하실 수 있답니다.  투시는 어떻게 배우느냐에 따라 무척 어렵게 다가올 수도, 쉽게 다가올 수도 있어요. 포인트만 이해하셔도 충분해요. 제가 수년간 수천명을 가르쳐드린 팁으로 더 쉽게 알려드릴게요. 따라만 와주세요!    어반 드로잉은 결국 여러 대상이 한 곳에 모여 이루어져요. 길이나 건물의 외벽, 거리의 나무들까지 어떻게 표현하는지 배워보세요. 펜 하나만으로도 다양한 텍스처를 표현할 수 있어요. 여러 텍스처 표현 방법을 알게 되면 그걸 응용해서 또다른 대상을 묘사할 수 있고요. 창문과 간판도 어떻게 그리면 더 현실적이고 입체적으로 보이는지 배워봐요.     누구나 한 번쯤 여행지에서 풍경, 어반 드로잉을 해 보고 싶으실 거예요. 저와 함께 드로잉 이론에 따라 풍경과 어반 드로잉을 해봐요. 투시를 사용한 풍경 그리는 법부터 자연물, 건물 등을 그리는 다양한 펜 드로잉 팁도 가져가세요! 사실 여행지에서 풍경을 보며 단시간에 그림을 그리는 게 쉽진 않아요. 클래스에서 꼼꼼하고 정확하게 그리는 연습을 하면, 여행지에서도 직접 보고 꽤 멋진 그림을 완성하실 수 있답니다. 리니의 드로잉 기초와 함께 배우는 펜 드로잉 클래스입니다. '단순히 보고 따라 그리는 그림'이 아닌 '왜 이렇게 그려야 하는지 이해하고 그리는 그림'을 가르쳐 드려요. 언제까지 누군가의 드로잉 스타일을 따라 하기만 할 순 없죠. 이 클래스를 통해서, 드로잉 기초를 꼼꼼히 익힌 후에 자신만의 스타일을 차근차근 만들어나가셨으면 좋겠어요. 클래스101 | 세상의 모든 클래스, 클래스101
# 2    (+블라인드 컨티뉴) 컨투어 드로잉으로 인물 그리기 드로잉 도구 그리기 일상에서 만나는 소품 그리기 나의 여행 가방 그리기 영국 런던, 타워브릿지 프랑스 파리, 에펠탑과 카페 스페인 바르셀로나, 사그라다 파밀리아 성당         펜잡는 방법, 선 긋기 등 기초부터 탄탄하게! 일상에서부터 여행까지, 우리가 마주하는 것들 어디서부터 어떻게 그릴 것인가      일기를 쓰듯, 여행지에서 내가 보고 느낀 걸 그림으로 기록하면 어떨까요? 이 클래스에서는 컨투어 드로잉으로 일상부터 여행까지 함께 기록해 볼 거예요.  컨투어 드로잉은 Contour(윤곽)와 Drawing(주로 선으로 그린 그림)이 합쳐진 미술 용어입니다. 묘사보다는 형태에 집중해서 그리는 기법으로 빠른 시간 내에 그릴 수 있어 그림을 처음 접하시는 분들도 쉽게 접근하기 좋을 뿐 아니라, 관찰력과 형태력을 키울 수 있는 유용한 기법입니다. 긴 시간 그림을 그릴 수 없는 야외에서도 10분 정도의 짧은 시간으로 그림을 그릴 수 있어요.  사진으로 담는 여행지의 모습도 좋지만, 여행지에서 그린 그림들은 사진첩을 보는 것과는 또 다른 느낌이 듭니다. 그림으로 그리려면 하나하나 관찰하는 시간이 필요하기 때문에 더 많은 것이 보이게 되고 더 선명하게 기억되죠.  그림을 그리며 다른 여행자를 만나기도, 그림이 연결고리가 되어 또 다른 추억을 만들어 주기도 합니다. 일상으로 돌아와서도 가끔 그 그림들을 들여다보면 만났던 사람들과의 대화, 그때의 날씨와 온도, 내 모습과 감정들까지 더 생생하게 기억됩니다. 제 여행 드로잉은 2012년에 혼자 떠난 제주도가 시작이었습니다. 그동안 평가받던 그림이 아닌 ‘눈에 보이는, 그냥 내가 그리고 싶은 것들을 그리자’는 단순한 생각에서 시작했어요. 그리고 이 클래스를 준비하게 된 가장 큰 계기는 2017년에 떠난 6개월 정도의 유럽 여행이었습니다. 특히, 스페인의 세비야에서 33일간 머무르며 한 권의 스케치북을 가득 채운 여행 드로잉은 저에게 특별한 경험을 가져다주었습니다.  우리는 가끔 꼭 가고 싶었던 여행지에서 사진을 찍을 수 없는 경험을 하게 됩니다. 그럴 때 저는 컨투어 드로잉으로 기록합니다.  저는 피카소를 좋아해서 피카소가 태어난 집과 자주 갔던 장소들을 찾아다녔는데요, 말라가에 위치한 생가와 박물관은 사진 촬영이 금지된 곳이었습니다. 사람들이 지나다니는 좁은 공간이거나 부족한 시간 때문에 다른 곳처럼 1시간이 넘도록 그림을 그릴 수가 없었죠. 그래서 10분 정도 짧은 시간 내에 그릴 수 있는 컨투어 드로잉으로 남겼습니다.    그리고 감사하게도 그곳에서 그린 그림을 박물관과 바르셀로나의 Els 4Gats(피카소가 자주 갔던 레스토랑으로, 피카소 그림 중에 4 Cats로 알려진 곳)라는 곳에서 인스타그램에 리그램을 해주신 적이 있어요. 정말 기쁘고 의미 있는 기억으로 남아있어요.  여행 드로잉 수업을 듣고 여행지에서 직접 그림을 그리신 수강생분들의 작품입니다.  어떤 날은 세비야에서 활동 중인 화가의 집에 초대받아 작업실을 구경하기도 했고, 그림을 그리는 다른 여행자를 만나 서로의 스케치북을 보며 다녀온 여행에 대한 대화를 나누기도 했습니다. 그리고 컨투어 드로잉으로 간단히 그린 인물화를 선물로 드렸는데 감사하게도 그날의 식사를 대접받기도 했죠.   단순히 내 일기처럼 그림을 그리자는 마음에서 시작한 드로잉이 매개체가 되어 인연을 만들어 주었고 내 여행의 깊이를 더하기도 했습니다. 그 기억을 공유하고 함께 나누고 싶어 여행을 다녀온 뒤로 저는 작은 화실을 운영하며 여행 드로잉 수업을 하고 있습니다.  이 클래스에서 함께 할 컨투어 드로잉은 비교적 구하기 쉽고 휴대에 용이한 펜과 스케치북으로 짧은 시간 내에 느낌 있는 그림을 그릴 수 있는 매력적인 드로잉 기법입니다. 그림에 자신이 없는 분들에게도 쉽고 재미있는 여행 드로잉 tip을 알려 드립니다! 그동안 어렵게만 느껴졌던 그림도 잘 그려야 된다는 부담감은 내려놓고 천천히 저와 함께 그리시다 보면 그림이 새롭게 보이고, 그림을 그리는 스스로가 즐겁다면 분명 좋은 취미가 되실 겁니다.  여러분들도 다음 여행지에서 작은 스케치북과 펜을 들고 여행의 순간을 직접 그림으로 기록해 보는 건 어떨까요? 10\n:\n37\n:\n04\n남음  클래스101 | 세상의 모든 클래스, 클래스101
# 3    클래스101에서 가장 사랑받는 미술 도구! 마카 드로잉에 입문할 수 있는 두 가지 클래스를 모아봤어요. 마카는 휴대하기도 쉽고 다루기도 비교적 쉬워서 입문자분들에게 딱 맞는 도구랍니다. 마카 클래스 중 가장 인기있는 두 클래스를 통해 마카드로잉을 완벽정복해보세요! 일상을 특별하게 만들어줄 배성규의 <마카와 색연필로 그려내는 일상의 기록, 뜻밖의 풍경, 찰나의 순간>과 여행의 특별한 기억을 더욱 소중하게 기록하게 해줄 <마카와 펜, 드로잉북만 들고 떠나요! 마카로 담는 여행의 특별한 기억>과 함께라면 문제 없어요.  일상과 맞닿아있는 순간을 마카와 색연필로 그립니다. 누구나 가지고 있는 일상 속 이야기를 가지고 여러분과 함께 그림을 완성시켜 나갈 거예요. 그냥 지나치기 쉬운 어제의 일상, 하루하루가 꿈같은 겹겹의 오늘, 아직 오지 않은 설렘의 내일, 그 모든 순간을 이야기합니다. 저와 함께 그림을 그리는 시간에는 당신의 모든 순간이 이야기가 됩니다. 페이지를 아주 조금만 채우면 드넓은 공간이 상상의 몫으로 채워질 거예요.   펜의 기초부터 시작해 마카로 채색하는 방법으로 끝냅니다. '클래스를 마치고 나서도 내가 혼자서 응용해서 그릴 수 있느냐'를 가장 많이 고민하고 클래스를 만들었어요. 음식과 디저트, 기억에 남는 장소, 여행일지까지 그려보며 여행의 설렘을 그림에 그대로 담아보세요. 여행을 가서도 혼자서 슥슥 여행스케치를 즐길 수 있도록요!  10\n:\n37\n:\n00\n남음  클래스101 | 세상의 모든 클래스, 클래스101
# 4    여자 정면 드로잉 남자 이목구비/골격 차이 비교 반측면 드로잉 측면 드로잉 부드러운 반무테 채색 완성 다양한 머리카락 채색 연습 사진 참고하여 완성 사진 참고·응용하여 개성 있는 캐릭터 그리기 캐릭터 얼굴 구도와 비율 정면, 측면, 반측면 그리기       저는 어렸을 때부터 그림 그리는 것과 사람들에게 저만의 그림 팁을 알려주기를 즐겨 했어요. 그림에 대한 깊은 애정이 전공이 아님에도 스스로 그림 실력을 키우는 데 큰 도움이 되었어요.   지금까지도 저는 그림을 어떻게 더 매력적으로 그릴 수 있을지, 저만의 그림 노하우들을 어떻게 더 쉽게 전할 수 있을지 매일 고민하고 있어요. 이번 클래스가 여러분께 제가 지금까지 쌓아왔던 팁들을 최대한 많이 알려 드릴 수 있는 기회가 되었으면 합니다.:)  얼굴 드로잉은 묘사를 얹어가며 캐릭터의 인상과 특징을 직접 만들고, 섬세한 터치로 인물의 아름다움을 끌어내는 아주 흥미롭고 매력적인 드로잉이에요. 얼굴이 인물 전체적으로 차지하는 면적 자체는 크지 않지만, 그 안에서 표현할 수 있는 디테일은 그 어느 부분보다 무궁무진하답니다.   눈에 비친 빛으로 눈가의 촉촉함을 살리는 것, 립글로스를 바른 듯 광택 있는 입술을 표현하는 것, 속눈썹 한 올 한 올, 눈동자 동공의 띠 하나까지 신경 쓰는 것. 섬세함이 보태질수록 빨려 들어갈 듯 분위기 있는 그림이 완성되죠!   이번 클래스에서는 '인물의 얼굴 드로잉'에 대해서 집중적으로 배우실 수 있어요. 밑그림을 위한 '드로잉 기초'부터 부드럽게 '채색하는 방법'까지 모두 담았답니다.   얼굴 비율을 이해하기 쉽게 설명해 드리고, 각도별 구도도 다뤄볼 예정이에요. 많은 분이 어려워하시는 옆모습 구도도 사실 굉장히 쉽게 그릴 수 있다는 것! 꼭 알려 드리고 싶어요.   피부는 반무테, 머리카락은 무테 채색 방법으로 배우시게 될 거예요. 반무테인 피부 채색은 마지막에 선을 정리하는 식으로, 무테인 머리 채색은 아예 없이 브러쉬의 결 표현만으로 그림을 완성합니다. 반무테, 무테 채색 방법은 틀에 짜이지 않고 자유롭게 표현할 수 있다는 점에서 선을 완벽하게 따고 칠하는 채색 법과 큰 차이점을 가지고 있어요.   채색을 얹어가며 생김새, 머릿결 등의 수정이 쉬워 완성했을 때까지 큰 자유도를 준다는 점에서 아주 재밌는 채색 방법이죠. 오히려 선을 따고 채색했을 때보다 쉽다고 느끼실지도 몰라요!   사진을 모작하면, 비율과 구도에서 도움을 받을 수 있다는 장점이 있어요. 반면 창작을 하면 자신만의 그림체를 발전시키고 또 특색 있는 인물을 그리는 연습을 할 수 있는 장점이 있죠. 이 두 가지의 장점을 모아 사진을 참고·응용하며 창작하는 방식의 팁을 다뤄보려고 해요.   저는 인물 드로잉을 할 때 그 캐릭터만의 특색을 살리는 데에, 또 그림이기 때문에 사진과는 또 다른 매력을 표현하는 데에 집중해요. 피부가 매끈하고 보드라운 캐릭터가 있다면, 반면에 어떤 캐릭터는 얼굴에 주근깨가 있을 수 있고, 차분하고 조용한 성격의 캐릭터가 있다면 그 반대로 활발하고 짓궂은 성격의 캐릭터가 있겠죠?  사진을 참고하여 그려보는 시간을 통해 다양한 캐릭터를 연구하고 그 개성을 표현해내는 재미를 함께 느껴봤으면 합니다.  아이패드는 언제 어디서나 영감이 떠오를 때 바로바로 쉽게 그릴 수 있는 점, 그리고 종이에 그리듯 부드러운 터치감을 가지고 있으면서도 디지털 드로잉의 최장점인 수정 편의성까지 겸비한 점이 정말 매력적인 드로잉 도구예요.   저는 누워서 쉬다가도 번뜩 그리고 싶은 게 떠오르면 항상 침대 머리맡에 두는 아이패드를 꺼내 든답니다. 쉽게 그림을 그릴 수 있는 환경이 조성되니 더 가벼운 마음으로 편하게 그림을 그릴 수 있었고, 그게 그림을 더 사랑하고 즐길 수 있는 데에 도움을 줬어요.  '취미'라는 건 내 여가시간을 투자해 '즐기기' 위해 하는 일이에요. 하지만 오히려 취미였던 그림으로 인해 스트레스를 받았던 경험이 있진 않으셨나요? 처음이라 막막해서, 더 발전할 길이 보이지 않아서 등 다양한 이유가 있을 거예요. 저 또한 그 과정을 경험했기에 여러분은 보다 쉽게 극복했으면 하는 마음으로 제 경험을 토대로 한 드로잉의 팁들을 최대한 많이 알려 드리려고 합니다. 재밌어서 시작했던 그림 때문에 스트레스받는 일은 없으셨으면 해요!  그림을 그 자체로 재밌게 즐길 수 있도록 도와드릴게요. 인물 드로잉 클래스를 통해 그림을 더 사랑하게 되는 계기가 되었으면 합니다 :) 10\n:\n36\n:\n53\n남음  클래스101 | 세상의 모든 클래스, 클래스101
# 5   클래스101 | 세상의 모든 클래스, 클래스101
# 6     미국에서 먹은 토스트 브런치 잊지 못할 맛, 일본 라멘 & 스시 먹기 아까웠던 유럽의 디저트 & 케이크 빈티지한 일본 나고야 카페 맑은 날, 유럽의 골목길- 1점 투시 저녁, 도쿄 전통가옥 건물 풍경– 2점 투시 지도 형식으로 그려보는 프랑스 여행    라이너 펜의 기초부터 꿀팁까지 마카의 컬러를 유치하지 않게 사용하는 법 마카 A부터 Z까지, 다양한 채색법     안녕하세요, 또 한 번 만나 뵙게 된 일러스트레이터 리니(Rini) 입니다! 첫 클래스인 '어색한 그림은 이제 안녕! 드로잉 기초부터 시작하는 리니의 펜드로잉' 클래스를 많은 분들이 사랑해주신 덕분에, 이번엔 마카&펜을 이용한 여행/일상 드로잉 클래스를 열게 되었어요! 저는 평생 그림만 그려왔고, 당연하게 그림을 전공했어요. 이제는 그림 그리는 일이 직업이 되었고, 온라인과 오프라인을 넘나들며 수많은 분들과 클래스를 진행해왔어요. 덕분에 여러분께 제가 지금까지 쌓아온 드로잉 팁들을 마구마구 전해드릴 수 있게 되었어요!  요즘 여행, 어반 드로잉 클래스가 정말 인기 많죠. 그만큼 많은 분이 원하고 계시고요. 여행 드로잉이든 그 무엇이든 가장 중요한 것은, ‘클래스를 마치고 나서도 내가 혼자서 응용해서 그릴 수 있느냐’ 입니다! 여러분도 그걸 원하고 계시겠죠?  제가 저번 수업과 마찬가지로 항상 강조하는 수업 목표예요. 클래스를 들어도, 나중에 혼자 그리려니 뭐가 뭔지 모르겠고.. 잘 떠오르지도 않고.. 그런 경우가 많아요. 무작정 따라 그리는 것은 사실 큰 의미가 없어요. 그리는 방법과 왜 그렇게 그려야 하는지 이유를 배우고 이해하며 충분히 적용해보셔야 나중에도 혼자서 멋진 드로잉을 하실 수 있답니다.  핸드폰 하나로도 멋진 사진을 찍을 수 있는 이 시대에 왜 여행 드로잉을 그릴까요? 그 이유는 그때의 느낌을 오로지 나만의 감성과 방법으로 담아낼 수 있기 때문이라고 생각해요. 똑같은 것을 바라봐도, 느끼는 감정과 분위기는 사람마다 모두 달라요. 그걸 표현할 수 있는 게 바로 드로잉이고요. 내가 여행과 일상에서 느꼈던 그때의 분위기, 순간적인 감정을 어떻게 더 잘 담아낼 수 있는지, 우리 함께 그려봐요.  이번 클래스는 여행/일상 드로잉 꿀팁을 많이 알려드리려고 해요. 마카와 펜만으로도 다양한 느낌을 낼 수 있죠. 어디에 어떤 펜선을 사용하느냐에 따라서 그림이 확 살기도 하고, 어떤 색을 이용해서 채색하느냐에 따라서 그림 분위기가 반전되기도 해요.   마카를 처음 사용하시는 분들도 계시겠지만, 이미 사용해보신 분들도 계실 거예요. ‘대체 왜 마카는 내가 사용하면 어색하고, 유치하고.. 안 예쁠까?’ 고민하신 분들 분명히 계실 거라고 생각해요. 아직 마카에 대해 제대로 알지 못하시기 때문이에요. 마카의 기본적인 사용 방법, 세련된 컬러 조합법, 채색 방법까지 마카에 대해 좀 더 깊이 있게 배워가시길 바라요.  '저는 그림 그려본 적도 없어요. 제가 할 수 있을까요?' 제가 장담하고 말씀드릴게요. '네!!! 할 수 있어요!!!' 저는 클래스101 온라인 클래스와 오프라인 드로잉 클래스를 통해서 수많은 분들을 만나왔어요. 모두 그림을 처음 그리시는 분들이었고, 저와 헤어지실 땐 '이게 정말 처음 그린 사람이 그린 게 맞아?' 할 정도로 멋진 드로잉을 가져가셨어요. 여러분의 걱정과 달리, 그림을 처음 그리시더라도 따라오실 수 있어요. 여러분 스스로 모르고 계신 능력을 제가 꺼내드릴 거예요.   저의 ‘드로잉 기초부터 시작하는 리니의 펜드로잉' 클래스를 들으신 분들은, 이번 클래스에서는 여행드로잉에 필요한 임팩트를 배우시고 마카로 채색하는 법을 중점적으로 배운다고 생각해주세요-! 물론 전 수업에서 미처 알려드리지 못했던 꿀팁도 들어있고요.  여러분 모두 영상을 따라 한 단계씩 따라오다 보면 달라진 자신을 보며 뿌듯해질 거예요!  클래스101 | 세상의 모든 클래스, 클래스101
# 7      누적 찜수 2만개 드로잉 카테고리 베스트 1위 ! 둡의 인물드로잉을 연필 부터 채색까지를 꿀조합으로 만나보세요! 그동안 인물드로잉을 도전해 보고 싶었다면 미술 드로잉 1위 꿀조합 클래스를 추천 합니다  건조한 재료로 그리는 감정이 담긴 인물화! 연필 한 자루면 어떤 표정이든 문제 없어요. 슬픈 감정의 인물, 그윽한 눈빛이 강조된 인물, 촉촉한 느낌의 인물 등 모든 분위기를 그릴 수 있도록 해드릴게요. 연필 그림은 내가 움직인대로, 표현한대로 그 흔적이 고스란히 다 남는 작업이에요. 그래서 형태를 잡기 위해 그었던 보조선들도, 그렸던 형태에서 톤이 조금 벗어나도. 그 자체로 예술이 된답니다.     수채화 물감과 색연필을 사용해서 인물을 더욱 다채롭게 그려봐요! 연필보다 다채로운 색들을 표현할 수 있는 만큼 더 효과적이고, 더 조화롭게 쓸 수 있는 방법들을 알려 드립니다. 색감을 잘표현하기 위해서는 색의 3요소를 적절히 써주는 것이에요. 색을 잘 표현하는 방법과 조화를 피부결과 얼굴면의 흐름에 따라 채색하는 법을 알면 여러분들만의 색감으로 채색 하실 수 있을 거에요.  클래스101 | 세상의 모든 클래스, 클래스101
# 8       안녕하세요, 소은 박경선입니다. 이 클래스는 인체드로잉에 조금 쉽게 다가가보는 수업입니다.  저는 우리가 늘 마주하고 함께하는 사람에 관심이 많아요. 그리고 그들의 마음에도 관심이 많아요. 사람을 그린다는 것은 어쩌면 나의 마음을 그리고 그들의 마음을 그리는 것이 아닐까 생각합니다.  근데 저는 사람을 어색하지 않게 그려내기까지 시간이 참 많이 걸렸던 것 같아요. 시중엔 너무 방대한 자료들 뿐이고 인체에 대해선 어디에서도 알려주는 곳이 없었거든요. 그래서 이 클래스에서 제가 오랫동안 고민하고 연구한 인체에 대한 팁에 관해서 다루어 볼까합니다.  인체를 파악할 때 가장 중요한 것은 인체 골격의 구조를 파악하는 거예요. 근데 이 구조를 파악하는 순서와 방법이 중요해요. 그래서 이 수업에서는 쉽고 간단하게 구조를 파악하는 방법과 무엇부터 그려내야 인체의 동세가 어색하지 않게 그려질 수 있는지 제가 터득한 노하우를 모두 알려드릴게요.  그리고 인체의 큰 구조를 익혔다면 그 구조에 근육을 그려보는 시간을 가질 거예요. 근데 사람의 몸엔 수많은 근육들이 있잖아요. 그 중에서 인체의 형태를 결정하는데 지대한 영향을 주는 핵심적인 근육만을 집중적으로 차근차근 배워볼 거예요.   손과 발은 인체에서 매우 작은 부분이라고 생각하실 수도 있지만 어찌보면 그림의 완성도를 높여주는 중요한 부분일지도 몰라요. 손과 발을 생략하더라도 그 구조를 파악하고 간략하게 그리는 것과 그저 잘 몰라서 얼버무리는 것과는 확연히 다르거든요. 이 수업에서는 다양한 손과 발의 각도를 가지고 쉽게 구조를 파악하는 방법을 알려드릴게요.  인체를 그릴 때는 얼굴을 디테일하게 그려내진 않지만 얼굴의 방향성이나 눈,코,입의 위치는 정확한 자리에 위치하고 있는 것이 좋아요. 그래서 얼굴의 기본구조를 이해하고 계신다면 얼굴 또한 어색하지 않게 그려내실 수 있답니다. 그래서 제가 공부한 여러가지 자료들과 제가 직접 그리면서 알고 있으면 좋았던 팁들을 알려드릴게요.  마지막으로 지금까지 배운 수업으로 좋아하는 인물을 그리는 시간을 가지려합니다. 더불어 그림을 그릴 때 어떠한 포인트를 가지면 자신만의 느낌을 가지는 그림을 그릴 수 있는지, 같은 스케치인데, 딱 하나만 바꾸면 느낌있는 그림이 되는 방법도 알려드릴게요!       안녕하세요, 소은 박경선입니다. 저의 기초 인체 드로잉 클래스에 이어 조금은 깊이 있게 인체 드로잉에 다가가 보는 클래스로 찾아왔어요. 첫 번째 클래스가 인체에 대한 막연한 두려움을 가지신 분들에게 조금은 쉽게 인체에 다가가게 해 드렸다면 이번 클래스는 본격적으로 '인체를 공부하는 단계'라고 생각해 주시면 좋을 것 같아요.   지금까지 기본적인 사람의 형태를 기반으로 인체를 배웠지만, 실제 사람은 마르거나 살집이 있거나 근육이 많은 편인 등등 너무나 다양하죠. 보다 사실감이 느껴질 수 있도록 체형별 특징과 표현법에 대해서 공부해 봅니다. 인체의 기본 구조에 대해 배워보고, 다양한 체형에 적용해보며 실제 사용 방법을 익혀 보아요.  항상 같은 나이 때의 인물만 그리고 있지는 않나요? 그릴 수 있는 대상이 한정적인 상태를 넘어, 보다 다양한 사람을 그리기 위하여 연령대별 인체의 특징과 표현법을 알아봅니다. 아이와 청년, 노인의 인체를 묘사하는 방법을 연습해요.  사람은 여러 가지 감정을 가지고 있기에 다양한 표정을 지을 수 있습니다. 그리고 사람의 마음과 개성은 얼굴 표정에서 가장 잘 표현되어요. 자연스러운 표정을 표현하기 위해서는 얼굴 근육의 구조를 이해하는 것이 필수입니다. 근육의 위치와 표정에 따른 움직임을 배워 볼 거예요.  그리고 머리카락 그리는 법도 배워볼 거예요. 한 올 한 올 머릿결, 헤어스타일에서도 사람의 특징은 잘 표현됩니다. 머리카락의 구조를 이해하고, 질감과 결의 표현은 어떻게 하는지 알아봅니다. 숏컷, 단발, 긴 생머리, 웨이브 머리 네 가지의 스타일을 그려보아요.  발은 이해했지만 신발이 잘 안 그려진다는 분들이 많아요. 사실 신발은 발과 크게 차이는 없지만 종류가 워낙 다양해서 그래요. 그림의 완성도를 높여주는 다양한 신발을 저와 함께 그려볼 거예요. 운동화, 구두, 하이힐을 그려보며 신발의 앞 모양뿐 아니라 뒷모습과 옆모습을 그리는 방법을 익혀 봅니다.  어쩌면 이번 심화 클래스는 마냥 즐겁거나 쉽게 느껴지지 않을 수도 있어요. 가볍게 즐기는 것 보다는 연구하고 공부하는 느낌이 많이 드실 거예요. 하지만 한 발 한 발 나아간다면, 여러분이 꿈꾸는 모든 인물을 그릴 수 있게 될 거예요. 여러분의 그림 실력이 성장하는데 밑거름이 되는 클래스가 되기를 바랍니다.   클래스101 | 세상의 모든 클래스, 클래스101
# 9    라인드로잉 - 유칼립투스 라인드로잉 - 새 명암드로잉 - 튤립 명암드로잉 - 나무 1점투시 풍경화 - 러프스케치 오로라가 있는 풍경 은하수가 있는 풍경    콘테, 연필, 목탄을 이용한 선과 톤 그림의 첫 시작, 라인 드로잉 입체감을 위한 명암 드로잉       회화를 전공하고 드로잉과 유화를 기반으로 작품을 하고 있습니다. 현재 아트스튜디오를 운영하며 다양한 연령대의 사람들을 가르치는 재미에 푹 빠져 있는데요, 그 중에서도 제가 즐겁게 작업하는 풍경드로잉을 소개하려고 합니다.    저는 저를 둘러싸고 있는 풍경에 관심이 많습니다. 평소 자연을 좋아하고 사랑해서 작품 대부분의 주제가 가까이에 있는 자연이었고, 그걸 가장 편하게 담을 수 있는 장르가 풍경화였던 것 같아요. 풍경을 담았던 긴 시간동안 제가 느낀 그림의 매력을 전달하고자 합니다.    풍경은 정적입니다. 말을 하지 않지만, 그 풍경을 바라보는 나의 감정이 말을 합니다. 담담하고 잔잔한 곳에서 갑자기 느껴지는 묘한 에너지라던가, 화려하고 강한 풍경에서 느껴지는 어떤 쓸쓸함 같은 것. 보이는 것 너머의 무언가를 담아내는건 예술가만 할 수 있는 특권이 아니랍니다. 바로 “내가 보는 것”을 담으면 되는 것 아닐까요.      잘 그리는 것도 중요하지만, 제 클래스의 기본적인 목표는 "내가 표현하고자 하는 것"을 그리는 것입니다. 남이 표현해놓은 시선보다 내가 느낀 것을 그릴 수 있게 하는 것이 제가 수업을 하는 가장 큰 이유이고 보람이에요.  드로잉으로 풍경화를 담으면 과연 어떤 매력이 있을까요? 언뜻 생각하면 색채도 없고 재료가 너무 단순하지요. 이걸 말씀드리고 싶어요. 화가들이 큰 작품을 들어가기 전에 에스키스, 즉 밑그림을 그리는 구상단계가 있는데 아이러니하게도 최종 작품이 그 스케치의 느낌을 못 따라갈 때가 정말 많아요.    긴 시간을 그리다 보면 첫 감정이 퇴색되기도 하고, 중압감 없이 편한 재료로 그릴 때 말하고자 하는 바를 뾰족하게 담아낼 수 있기 때문입니다. 드로잉은 그런 직관적인 매력이 있어요. 콘테(Conté)는 연필보다 색감이 강하고, 목탄보다는 깔끔하게 표현되는 소묘 재료입니다. 블렌딩이 부드럽고 명암이 강해 초보자들도 원하는 느낌이 잘 표현되곤 해요. 이 수업에서 중점적으로 쓸 재료입니다.  그림을 처음 그리는 사람에게 색을 써보게 하면 아쉽게도 1차원적인 느낌이 나올 때가 많아요. 톤이나 양감을 표현하는 방법이 익숙하지 않기에 평면적인 그림이 되기 쉽거든요. 좋은 그림을 위해서는 “톤”을 익혀보세요. 그래야 꼭 그 자리에 있어야 할 색을 얹을 수 있어요. 이 클래스는 연필, 콘테, 목탄을 모두 다루기 때문에, 자신에게 맞는 드로잉도구도 찾을 수 있는 좋은 기회가 될 것 같아요.   수업에서는 그림의 아주 기초적 스킬부터 습득하게 될 것입니다. 먼저 자연물을 하나씩 화면에 담아보고, 나무와 길을 그리다가 이후에는 이국적이고 아름다운 풍경까지 묘사해보게 됩니다.       소설과 시가 가진 매력이 다르듯이 드로잉이 가진 단순하고 군더더기없는 본질적인 매력은 그림과 나를 정면으로 마주보게 합니다. 처음에는 어색해도 계속해서 그리다보면 나만의 선, 나만의 완성도를 가질 수 있게 된답니다.  이 클래스를 통해 자유롭게 그리는 즐거움을 꼭 만나시길 바랄게요. 수업시간에 만나요! 10\n:\n36\n:\n22\n남음  클래스101 | 세상의 모든 클래스, 클래스101
# ...
# 57  클래스101 | 세상의 모든 클래스, 클래스101
# 58  클래스101 | 세상의 모든 클래스, 클래스101
# 59  클래스101 | 세상의 모든 클래스, 클래스101
#
#    keyword
# 0   드로잉
# 1   드로잉
# 2   드로잉
# 3   드로잉
# 4   드로잉
# 5   드로잉
# 6   드로잉
# 7   드로잉
# 8   드로잉
# 9   드로잉
# 10  드로잉
# 11  드로잉
# 12  드로잉
# 13  드로잉
# 14  드로잉
# 15  드로잉
# 16  드로잉
# 17  드로잉
# 18  드로잉
# 19  드로잉
# 20  드로잉
# 21  드로잉
# 22  드로잉
# 23  드로잉
# 24  드로잉
# 25  드로잉
# 26  드로잉
# 27  드로잉
# 28  드로잉
# 29  드로잉
# 30  드로잉
# 31  드로잉
# 32  드로잉
# 33  드로잉
# 34  드로잉
# 35  드로잉
# 36  드로잉
# 37  드로잉
# 38  드로잉
# 39  드로잉
# 40  드로잉
# 41  드로잉
# 42  드로잉
# 43  드로잉
# 44  드로잉
# 45  드로잉
# 46  드로잉
# 47  드로잉
# 48  드로잉
# 49  드로잉
# 50  드로잉
# 51  드로잉
# 52  드로잉
# 53  드로잉
# 54  드로잉
# 55  드로잉
# 56  드로잉
# 57  드로잉
# 58  드로잉
# 59  드로잉

# %% [markdown]
# ### 중간에 강의 소개글에 '클래스101 | 세상의 모든 클래스, 클래스101	' 라고 입력된 건들은  경로 상의 문제인지, 다른 문제인지확인 필요함
